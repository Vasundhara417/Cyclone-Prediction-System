# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("C:\\Users\\chvas\\Downloads\\pacific.csv")

# %%
data.head()
# Out:
#          ID                 Name      Date  Time Event Status Latitude  \
# 0  EP011949              UNNAMED  19490611     0           TS    20.2N
# 1  EP011949              UNNAMED  19490611   600           TS    20.2N
# 2  EP011949              UNNAMED  19490611  1200           TS    20.2N
# 3  EP011949              UNNAMED  19490611  1800           TS    20.3N
# 4  EP011949              UNNAMED  19490612     0           TS    20.4N
#
#   Longitude  Maximum Wind  Minimum Pressure  ...  Low Wind SW  Low Wind NW  \
# 0    106.3W            45              -999  ...         -999         -999
# 1    106.4W            45              -999  ...         -999         -999
# 2    106.7W            45              -999  ...         -999         -999
# 3    107.7W            45              -999  ...         -999         -999
# 4    108.6W            45              -999  ...         -999         -999
#
#    Moderate Wind NE  Moderate Wind SE  Moderate Wind SW  Moderate Wind NW  \
# ...

# %%
data.shape
# Out:
# (26137, 22)

# %%
data.dropna()
# Out:
#              ID                 Name      Date  Time Event Status Latitude  \
# 0      EP011949              UNNAMED  19490611     0           TS    20.2N
# 1      EP011949              UNNAMED  19490611   600           TS    20.2N
# 2      EP011949              UNNAMED  19490611  1200           TS    20.2N
# 3      EP011949              UNNAMED  19490611  1800           TS    20.3N
# 4      EP011949              UNNAMED  19490612     0           TS    20.4N
# ...         ...                  ...       ...   ...   ...    ...      ...
# 26132  EP222015               SANDRA  20151128  1200           LO    21.7N
# 26133  EP222015               SANDRA  20151128  1800           LO    22.4N
# 26134  EP222015               SANDRA  20151129     0           LO    23.1N
# 26135  EP222015               SANDRA  20151129   600           LO    23.5N
# 26136  EP222015               SANDRA  20151129  1200           LO    24.2N
#
#       Longitude  Maximum Wind  Minimum Pressure  ...  Low Wind SW  \
# ...

# %%
data.groupby(['Status'])['Status'].count().plot(kind='bar',title="Status vs Count",ylabel="Count",fontsize=20,figsize=(10,10),color='green')
# Out:
# <Axes: title={'center': 'Status vs Count'}, xlabel='Status', ylabel='Count'>

# %%
sns.barplot(x='Status',y='Minimum Pressure',data=data)
# Out:
# <Axes: xlabel='Status', ylabel='Minimum Pressure'>

# %%
sns.barplot(x='Maximum Wind',y='Status',data=data,palette="Blues_d")
# Out:
# <Axes: xlabel='Maximum Wind', ylabel='Status'>

# %%
data.Status=pd.Categorical(data.Status)
data['Status']=data.Status.cat.codes
data.head()
# Out:
#          ID                 Name      Date  Time Event  Status Latitude  \
# 0  EP011949              UNNAMED  19490611     0            10    20.2N
# 1  EP011949              UNNAMED  19490611   600            10    20.2N
# 2  EP011949              UNNAMED  19490611  1200            10    20.2N
# 3  EP011949              UNNAMED  19490611  1800            10    20.3N
# 4  EP011949              UNNAMED  19490612     0            10    20.4N
#
#   Longitude  Maximum Wind  Minimum Pressure  ...  Low Wind SW  Low Wind NW  \
# 0    106.3W            45              -999  ...         -999         -999
# 1    106.4W            45              -999  ...         -999         -999
# 2    106.7W            45              -999  ...         -999         -999
# 3    107.7W            45              -999  ...         -999         -999
# 4    108.6W            45              -999  ...         -999         -999
#
#    Moderate Wind NE  Moderate Wind SE  Moderate Wind SW  Moderate Wind NW  \
# ...

# %%
pred_columns = data[:]
pred_columns.drop(['Status'],axis=1,inplace=True)
pred_columns.drop(['Event'],axis=1,inplace=True)
pred_columns.drop(['Latitude'],axis=1,inplace=True)
pred_columns.drop(['Longitude'],axis=1,inplace=True)
pred_columns.drop(['ID'],axis=1,inplace=True)
pred_columns.drop(['Name'],axis=1,inplace=True)
pred_columns.drop(['Date'],axis=1,inplace=True)
pred_columns.drop(['Time'],axis=1,inplace=True)
prediction_var = pred_columns.columns
print(list(prediction_var))
# Out:
# ['Maximum Wind', 'Minimum Pressure', 'Low Wind NE', 'Low Wind SE', 'Low Wind SW', 'Low Wind NW', 'Moderate Wind NE', 'Moderate Wind SE', 'Moderate Wind SW', 'Moderate Wind NW', 'High Wind NE', 'High Wind SE', 'High Wind SW', 'High Wind NW']

# %%
data.groupby(['Status'])['Status'].sum()
# Out:
# Status
# 0          0
# 1        152
# 2        220
# 3      20298
# 4       7312
# 5         30
# 6         24
# 7         49
# 8         48
# 9      62685
# 10    100760
# Name: Status, dtype: int64

# %%
from sklearn.model_selection  import train_test_split
train, test = train_test_split(data, test_size = 0.3)

# %%
train
# Out:
#              ID                 Name      Date  Time Event  Status Latitude  \
# 2860   EP051967              ELEANOR  19670717     0             9    20.1N
# 25392  EP202014                TRUDY  20141019     0             9    17.3N
# 17462  EP041998                CELIA  19980718     0            10    19.4N
# 14284  EP081992            GEORGETTE  19920722  1200             3    17.9N
# 12045  EP111988               KRISTY  19880905     0             9    19.0N
# ...         ...                  ...       ...   ...   ...     ...      ...
# 8427   EP081982               HECTOR  19820730   600            10    12.1N
# 24289  CP022013                UNALA  20130817   600             0    13.6N
# 20078  EP132004               JAVIER  20040915   600             3    17.7N
# 25378  CP022014                  ANA  20141025   600             3    31.7N
# 18689  EP112001             JULIETTE  20010922     0            10    13.6N
#
# ...

# %%
train_x = train[prediction_var]
train_x
# Out:
#        Maximum Wind  Minimum Pressure  Low Wind NE  Low Wind SE  Low Wind SW  \
# 2860             25              -999         -999         -999         -999
# 25392            25              1007            0            0            0
# 17462            40              1001         -999         -999         -999
# 14284            70               984         -999         -999         -999
# 12045            25              1012         -999         -999         -999
# ...             ...               ...          ...          ...          ...
# 8427             50              -999         -999         -999         -999
# 24289            25              1010            0            0            0
# 20078           125               936          100          100          100
# 25378            65               987          100          100           70
# 18689            40               996         -999         -999         -999
#
# ...

# %%
train_y= train['Status']  
train_y
# Out:
# 2860      9
# 25392     9
# 17462    10
# 14284     3
# 12045     9
#          ..
# 8427     10
# 24289     0
# 20078     3
# 25378     3
# 18689    10
# Name: Status, Length: 18295, dtype: int8

# %%
test_x= test[prediction_var] 
test_y =test['Status']
print(list(test.columns))
# Out:
# ['ID', 'Name', 'Date', 'Time', 'Event', 'Status', 'Latitude', 'Longitude', 'Maximum Wind', 'Minimum Pressure', 'Low Wind NE', 'Low Wind SE', 'Low Wind SW', 'Low Wind NW', 'Moderate Wind NE', 'Moderate Wind SE', 'Moderate Wind SW', 'Moderate Wind NW', 'High Wind NE', 'High Wind SE', 'High Wind SW', 'High Wind NW']

# %%
from sklearn.svm import LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
svc=LinearSVC()
TREE = DecisionTreeClassifier (criterion = 'entropy')
TREE_GINI = DecisionTreeClassifier (criterion = 'gini')
RF = RandomForestClassifier(n_estimators=100, criterion='entropy')

# %%
from sklearn.ensemble import VotingClassifier
Ens = VotingClassifier( estimators= [('RF',RF),('DT1',TREE_GINI),('SVM',svc),('DT',TREE)], voting = 'hard')

# %%
prediction_var=['Maximum Wind','Minimum Pressure','Low Wind NE','Low Wind NW']
train,test=train_test_split(data,test_size=0.3,random_state=42)

# %%
train_x = train[prediction_var]
train_y = train['Status']
test_x = test[prediction_var]
test_y = test['Status']

# %%
svc = LinearSVC()
TREE = DecisionTreeClassifier(criterion='entropy')
RF = RandomForestClassifier(n_estimators=100)

# %%
Ens = VotingClassifier(estimators=[('svc', svc), ('tree', TREE), ('rf', RF)], voting='hard')

Ens.fit(train_x,train_y)
# Out:
# VotingClassifier(estimators=[('svc', LinearSVC()),
#                              ('tree',
#                               DecisionTreeClassifier(criterion='entropy')),
#                              ('rf', RandomForestClassifier())])

# %%
accuracy = Ens.score(test_x, test_y)
print('Accuracy score of Ensemble Learning is = {:.2f}'.format(accuracy),'%')
# Out:
# Accuracy score of Ensemble Learning is = 0.96 %
